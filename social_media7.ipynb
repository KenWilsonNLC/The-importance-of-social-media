# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://soax.com/research/time-spent-on-social-media"

response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

tables = soup.find_all('table')

if len(tables) >= 7:
    seventh_table = tables[6]
    rows = seventh_table.find_all('tr')

    reasons = []
    percentages = []

    for row in rows[1:]:
        cols = row.find_all('td')
        if len(cols) == 2:
            reasons.append(cols[0].text.strip())
            percentages.append(cols[1].text.strip())

    reasons = pd.DataFrame({
        'Reason': reasons,
        'Percentage (%)': percentages
    })

# %%
reasons
# Out:
#                                           Reason Percentage (%)
# 0       Keeping in touch with friends and family         49.50%
# 1                             Filling spare time         38.50%
# 2                           Reading news stories         34.20%
# 3       Finding content (e.g., articles, videos)         30.20%
# 4               Seeing what's being talked about         28.70%
# 5   Finding inspiration for things to do and buy         26.70%
# 6                   Finding products to purchase         26.10%
# 7    Sharing and discussing opinions with others         22.70%
# 8                          Watching live streams         22.70%
# 9                            Making new contacts         22.50%
# 10      Seeing content from your favorite brands         22.10%
# 11                  Watching or following sports         22.00%
# 12           Work-related networking or research         21.30%
# 13          Following celebrities or influencers         20.10%
# 14                       Posting about your life         19.70%
